# %%
import requests

url = "https://api.usaspending.gov/api/v2/search/spending_by_award/"

payload = {
    "filters": {
        "time_period": [
            {"start_date": "2023-01-01", "end_date": "2023-12-31"}
        ],
        "award_type_codes": ["A","B","C","D"]
    },
    "fields": [
        "Base Obligation Date",
        "Award Amount",
        "Recipient Name",
        "Description"
    ],
    "limit": 5
}

response = requests.post(url, json=payload)
data = response.json()

# Mostrar los resultados
data
# Out:
# {'spending_level': 'awards',
#  'limit': 5,
#  'results': [{'internal_id': 350479995,
#    'Base Obligation Date': '2023-12-31',
#    'Award Amount': 2718.57,
#    'Recipient Name': 'PAJU SANITATION CORP.',
#    'Description': 'STAND ALONE CAR DEC 2023',
#    'generated_internal_id': 'CONT_AWD_W91QVN24F5018_9700_W91QVN23A0015_9700'},
#   {'internal_id': 350479993,
#    'Base Obligation Date': '2023-12-31',
#    'Award Amount': 7889.61,
#    'Recipient Name': 'KOREA HOUSING MANAGEMENT CO.,LTD',
#    'Description': 'STAND ALONE CAR DEC 2023',
#    'generated_internal_id': 'CONT_AWD_W91QVN24F5017_9700_W91QVN19D0046_9700'},
#   {'internal_id': 350193100,
#    'Base Obligation Date': '2023-12-31',
#    'Award Amount': 126244.26,
#    'Recipient Name': 'GPC CONSOLIDATED REPORTING',
#    'Description': 'CONSOLIDATED QUARTERLY (1QFY24) REPORTING OF GPC PURCHASES ABOVE THE MPT MADE IN USD.',
#    'generated_internal_id': 'CONT_AWD_W912PF24PV002_9700_-NONE-_-NONE-'},
#   {'internal_id': 350193099,
#    'Base Obligation Date': '2023-12-31',
#    'Award Amount': 232440.24,
#    'Recipient Name': 'GPC FOREIGN CONTRACTOR CONSOLIDATED REPORTING',
#    'Description': 'CONSOLIDATED QUARTERLY (1QFY24) REPORTING OF GPC PURCHASES ABOVE THE MPT MADE IN EUR.',
#    'generated_internal_id': 'CONT_AWD_W912PF24PV001_9700_-NONE-_-NONE-'},
#   {'internal_id': 349199182,
#    'Base Obligation Date': '2023-12-31',
#    'Award Amount': 520635.33,
#    'Recipient Name': 'GOVERNMENT ACQUISITIONS INC',
#    'Description': 'RENEWAL FY24 NUTANIX LICENSE',
#    'generated_internal_id': 'CONT_AWD_W9113M24F0005_9700_W52P1J16D0019_9700'}],
#  'page_metadata': {'page': 1,
#   'hasNext': True,
#   'last_record_unique_id': 349199182,
#   'last_record_sort_value': '1703980800000'},
#  'messages': ['For searches, time period start and end dates are currently limited to an earliest date of 2007-10-01.  For data going back to 2000-10-01, use either the Custom Award Download feature on the website or one of our download or bulk_download API endpoints as listed on https://api.usaspending.gov/docs/endpoints. ']}

# %%
import pandas as pd

# Convertir lista de resultados a DataFrame
df = pd.DataFrame(data["results"])

# Guardar a CSV
df.to_csv("compras_api.csv", index=False)

# Guardar a JSON
df.to_json("compras_api.json", orient="records", indent=2)

df.head()  # Muestra los primeros 5 registros
# Out:
#    internal_id Base Obligation Date  Award Amount  \
# 0    350479995           2023-12-31       2718.57
# 1    350479993           2023-12-31       7889.61
# 2    350193100           2023-12-31     126244.26
# 3    350193099           2023-12-31     232440.24
# 4    349199182           2023-12-31     520635.33
#
#                                   Recipient Name  \
# 0                          PAJU SANITATION CORP.
# 1               KOREA HOUSING MANAGEMENT CO.,LTD
# 2                     GPC CONSOLIDATED REPORTING
# 3  GPC FOREIGN CONTRACTOR CONSOLIDATED REPORTING
# 4                    GOVERNMENT ACQUISITIONS INC
#
#                                          Description  \
# 0                           STAND ALONE CAR DEC 2023
# 1                           STAND ALONE CAR DEC 2023
# 2  CONSOLIDATED QUARTERLY (1QFY24) REPORTING OF G...
# 3  CONSOLIDATED QUARTERLY (1QFY24) REPORTING OF G...
# 4                       RENEWAL FY24 NUTANIX LICENSE
#
#                             generated_internal_id
# 0  CONT_AWD_W91QVN24F5018_9700_W91QVN23A0015_9700
# 1  CONT_AWD_W91QVN24F5017_9700_W91QVN19D0046_9700
# 2       CONT_AWD_W912PF24PV002_9700_-NONE-_-NONE-
# 3       CONT_AWD_W912PF24PV001_9700_-NONE-_-NONE-
# 4  CONT_AWD_W9113M24F0005_9700_W52P1J16D0019_9700

# %%
# Guardar DataFrame en CSV
df.to_csv("compras_api.csv", index=False)

# Guardar DataFrame en JSON
df.to_json("compras_api.json", orient="records", indent=2)

print("Archivos guardados correctamente")
# Out:
# Archivos guardados correctamente

# %%
# Crear columna tipo de activo según descripción
def tipo_activo(desc):
    desc = desc.lower()
    if "it" in desc or "computer" in desc:
        return "Computadora"
    elif "furniture" in desc or "desk" in desc:
        return "Mobiliario"
    elif "license" in desc:
        return "Licencia de software"
    else:
        return "Otro"

df["Tipo de Activo"] = df["Description"].apply(tipo_activo)
df["Fecha de Compra"] = df["Base Obligation Date"]
df["Costo"] = df["Award Amount"]
df["Proveedor"] = df["Recipient Name"]

# Asignar vida útil aproximada
def vida_util(tipo):
    if tipo == "Computadora":
        return 5
    elif tipo == "Mobiliario":
        return 10
    elif tipo == "Licencia de software":
        return 3
    else:
        return 5

df["Vida Útil (años)"] = df["Tipo de Activo"].apply(vida_util)
df["Ubicación"] = "ACC – Campus Principal"

# Mostrar tabla final de activos fijos
df_final = df[["Tipo de Activo","Fecha de Compra","Costo","Proveedor","Vida Útil (años)","Ubicación"]]
df_final
# Out:
#          Tipo de Activo Fecha de Compra      Costo  \
# 0                  Otro      2023-12-31    2718.57
# 1                  Otro      2023-12-31    7889.61
# 2                  Otro      2023-12-31  126244.26
# 3                  Otro      2023-12-31  232440.24
# 4  Licencia de software      2023-12-31  520635.33
#
#                                        Proveedor  Vida Útil (años)  \
# 0                          PAJU SANITATION CORP.                 5
# 1               KOREA HOUSING MANAGEMENT CO.,LTD                 5
# 2                     GPC CONSOLIDATED REPORTING                 5
# 3  GPC FOREIGN CONTRACTOR CONSOLIDATED REPORTING                 5
# 4                    GOVERNMENT ACQUISITIONS INC                 3
#
#                 Ubicación
# 0  ACC – Campus Principal
# 1  ACC – Campus Principal
# 2  ACC – Campus Principal
# 3  ACC – Campus Principal
# 4  ACC – Campus Principal

# %%
# Guardar la tabla final de activos fijos
df_final.to_csv("activos_fijos_acc.csv", index=False)
df_final.to_json("activos_fijos_acc.json", orient="records", indent=2)

print("Tabla final de activos fijos guardada correctamente")
# Out:
# Tabla final de activos fijos guardada correctamente

# %%
from google.colab import files

# Descargar CSV
files.download("activos_fijos_acc.csv")

# Descargar JSON
files.download("activos_fijos_acc.json")

# %%
import pandas as pd
from datetime import datetime, timedelta

# Convertir Fecha de Compra a datetime
df_final["Fecha de Compra"] = pd.to_datetime(df_final["Fecha de Compra"])

# Crear columna de fecha de reemplazo
df_final["Fecha de Reposición"] = df_final["Fecha de Compra"] + pd.to_timedelta(df_final["Vida Útil (años)"]*365, unit='d')

# Mostrar tabla con fechas de compra y reposición
df_final[["Tipo de Activo","Fecha de Compra","Costo","Vida Útil (años)","Fecha de Reposición"]]
# Out:
# /tmp/ipython-input-3216402840.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["Fecha de Compra"] = pd.to_datetime(df_final["Fecha de Compra"])
# /tmp/ipython-input-3216402840.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["Fecha de Reposición"] = df_final["Fecha de Compra"] + pd.to_timedelta(df_final["Vida Útil (años)"]*365, unit='d')
#          Tipo de Activo Fecha de Compra      Costo  Vida Útil (años)  \
# 0                  Otro      2023-12-31    2718.57                 5
# 1                  Otro      2023-12-31    7889.61                 5
# 2                  Otro      2023-12-31  126244.26                 5
# 3                  Otro      2023-12-31  232440.24                 5
# 4  Licencia de software      2023-12-31  520635.33                 3
#
#   Fecha de Reposición
# 0          2028-12-29
# 1          2028-12-29
# 2          2028-12-29
# 3          2028-12-29
# 4          2026-12-30

# %%
import pandas as pd
from datetime import datetime, timedelta

# Convertir Fecha de Compra a datetime
df_final["Fecha de Compra"] = pd.to_datetime(df_final["Fecha de Compra"])

# Crear columna de fecha de reemplazo
df_final["Fecha de Reposición"] = df_final["Fecha de Compra"] + pd.to_timedelta(df_final["Vida Útil (años)"]*365, unit='d')

# Mostrar tabla con fechas de compra y reposición
df_final[["Tipo de Activo","Fecha de Compra","Costo","Vida Útil (años)","Fecha de Reposición"]]
# Out:
# /tmp/ipython-input-3216402840.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["Fecha de Compra"] = pd.to_datetime(df_final["Fecha de Compra"])
# /tmp/ipython-input-3216402840.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["Fecha de Reposición"] = df_final["Fecha de Compra"] + pd.to_timedelta(df_final["Vida Útil (años)"]*365, unit='d')
#          Tipo de Activo Fecha de Compra      Costo  Vida Útil (años)  \
# 0                  Otro      2023-12-31    2718.57                 5
# 1                  Otro      2023-12-31    7889.61                 5
# 2                  Otro      2023-12-31  126244.26                 5
# 3                  Otro      2023-12-31  232440.24                 5
# 4  Licencia de software      2023-12-31  520635.33                 3
#
#   Fecha de Reposición
# 0          2028-12-29
# 1          2028-12-29
# 2          2028-12-29
# 3          2028-12-29
# 4          2026-12-30

# %%
# Crear rango de años para la simulación
años = range(df_final["Fecha de Compra"].dt.year.min(), df_final["Fecha de Reposición"].dt.year.max()+1)

# Crear DataFrame de histórico anual
historial = []

for año in años:
    total_anual = df_final[df_final["Fecha de Compra"].dt.year <= año][df_final["Fecha de Reposición"].dt.year >= año].groupby("Tipo de Activo")["Costo"].sum().reset_index()
    total_anual["Año"] = año
    historial.append(total_anual)

df_historial = pd.concat(historial, ignore_index=True)

# Reordenar columnas
df_historial = df_historial[["Año","Tipo de Activo","Costo"]]

# Mostrar tabla histórica
df_historial
# Out:
#     Año        Tipo de Activo      Costo
# 0  2023  Licencia de software  520635.33
# 1  2023                  Otro  369292.68
# 2  2024  Licencia de software  520635.33
# 3  2024                  Otro  369292.68
# 4  2025  Licencia de software  520635.33
# 5  2025                  Otro  369292.68
# 6  2026  Licencia de software  520635.33
# 7  2026                  Otro  369292.68
# 8  2027                  Otro  369292.68
# 9  2028                  Otro  369292.68

# %%
reposiciones = []

for _, row in df_final.iterrows():
    fecha = row["Fecha de Reposición"]
    reposiciones.append({
        "Tipo de Activo": row["Tipo de Activo"],
        "Fecha de Reposición": fecha,
        "Costo": row["Costo"],
        "Proveedor": row["Proveedor"]
    })

df_reposiciones = pd.DataFrame(reposiciones)
df_reposiciones.sort_values("Fecha de Reposición", inplace=True)
df_reposiciones
# Out:
#          Tipo de Activo Fecha de Reposición      Costo  \
# 4  Licencia de software          2026-12-30  520635.33
# 0                  Otro          2028-12-29    2718.57
# 1                  Otro          2028-12-29    7889.61
# 2                  Otro          2028-12-29  126244.26
# 3                  Otro          2028-12-29  232440.24
#
#                                        Proveedor
# 4                    GOVERNMENT ACQUISITIONS INC
# 0                          PAJU SANITATION CORP.
# 1               KOREA HOUSING MANAGEMENT CO.,LTD
# 2                     GPC CONSOLIDATED REPORTING
# 3  GPC FOREIGN CONTRACTOR CONSOLIDATED REPORTING
